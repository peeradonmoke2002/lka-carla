# %%
import torch
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
from PIL import Image
import os
import pandas as pd
import seaborn as sns

# Check if CUDA is available
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")

# Set plotting style
plt.style.use('fivethirtyeight')
# %matplotlib inline
# Out:
# /home/peeradon/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# CUDA available: True
# CUDA device: NVIDIA GeForce RTX 3070 Ti

# %%
model = YOLO('/home/peeradon/lka-carla-yolo/yolo26n-seg.pt')

# %%
model.info()
# Out:
# YOLO26n-seg summary: 309 layers, 3,126,280 parameters, 0 gradients, 11.1 GFLOPs
# (309, 3126280, 0, 11.139097600000001)

# %%
# !nvidia-smi
# Out:
# Wed Apr 29 18:34:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.20             Driver Version: 580.126.20     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 53%   48C    P2            104W /  310W |    6131MiB /   8192MiB |     32%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2401      G   /usr/lib/xorg/Xorg                      301MiB |
# |    0   N/A  N/A            2547      G   /usr/bin/gnome-shell                     55MiB |
# |    0   N/A  N/A            3376      G   ...rack-uuid=3190708988185955192        147MiB |
# |    0   N/A  N/A            4928      G   /usr/share/code/code                    156MiB |
# |    0   N/A  N/A           63232      G   ...ess --variations-seed-version         24MiB |
# |    0   N/A  N/A          544839    C+G   ...Linux/CarlaUE4-Linux-Shipping       2859MiB |
# |    0   N/A  N/A          545619      C   ...onents/component_container_mt       1388MiB |
# |    0   N/A  N/A          546227      C   ...onents/component_container_mt        762MiB |
# |    0   N/A  N/A          546627      G   /opt/ros/humble/lib/rviz2/rviz2         276MiB |
# +-----------------------------------------------------------------------------------------+

# %%
results = model.train(
    data="/home/peeradon/lka-carla-yolo/lka.yolo26/data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,        # safe on 8GB with other processes running
    device=0,
    patience=20,
    project="training/runs",
    name="lka_seg_n",
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.43 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.7 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7832MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/peeradon/lka-carla-yolo/lka.yolo26/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/home/peeradon/lka-carla-yolo/yolo26n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=lka_seg_n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=training/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/peeradon/lka-carla-yolo/lka_ws/src/lka_dataset_collection/scripts/runs/segment/training/runs/lka_seg_n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    790886  ultralytics.nn.modules.head.Segment26        [2, 32, 64, 1, True, [64, 128, 256]]
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# YOLO26n-seg summary: 309 layers, 3,053,510 parameters, 3,053,510 gradients, 10.8 GFLOPs
#
# Transferred 740/844 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 34.8MB/s 0.2s.1s<0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4545.7±1708.7 MB/s, size: 467.5 KB)
# train: Scanning /home/peeradon/lka-carla-yolo/lka.yolo26/train/labels... 1600 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1600/1600 1.9Kit/s 0.9s0.0s
# train: New cache created: /home/peeradon/lka-carla-yolo/lka.yolo26/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3248.7±2299.2 MB/s, size: 480.2 KB)
# val: Scanning /home/peeradon/lka-carla-yolo/lka.yolo26/valid/labels... 400 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 400/400 986.0it/s 0.4s0.1s
# val: New cache created: /home/peeradon/lka-carla-yolo/lka.yolo26/valid/labels.cache
# Plotting labels to /home/peeradon/lka-carla-yolo/lka_ws/src/lka_dataset_collection/scripts/runs/segment/training/runs/lka_seg_n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 134 weight(decay=0.0), 154 weight(decay=0.0005), 154 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/peeradon/lka-carla-yolo/lka_ws/src/lka_dataset_collection/scripts/runs/segment/training/runs/lka_seg_n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
# : 0% ──────────── 0/200  1.0s
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 results = model.train(
#       2     data="/home/peeradon/lka-carla-yolo/lka.yolo26/data.yaml",
#       3     epochs=100,
#       4     imgsz=640,
#       5     batch=8,        # safe on 8GB with other processes running
#       6     device=0,
#       7     patience=20,
#       8     project="training/runs",
#       9     name="lka_seg_n",
#      10 )
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:774, in Model.train(self, trainer, **kwargs)
#     771     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     772     self.model = self.trainer.model
# --> 774 self.trainer.train()
#     775 # Update model and cfg after training
#     776 if RANK in {-1, 0}:
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/trainer.py:244, in BaseTrainer.train(self)
#     241         ddp_cleanup(self, str(file))
#     243 else:
# --> 244     self._do_train()
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/trainer.py:433, in BaseTrainer._do_train(self)
#     431     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     432 else:
# --> 433     loss, self.loss_items = self.model(batch)
#     434 self.loss = loss.sum()
#     435 if RANK != -1:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:141, in BaseModel.forward(self, x, *args, **kwargs)
#     128 """Perform forward pass of the model for either training or inference.
#     129
#     130 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)
#     138     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     139 """
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 141     return self.loss(x, *args, **kwargs)
#     142 return self.predict(x, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:332, in BaseModel.loss(self, batch, preds)
#     329     self.criterion = self.init_criterion()
#     331 if preds is None:
# --> 332     preds = self.forward(batch["img"])
#     333 return self.criterion(preds, batch)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:311, in C2f.forward(self, x)
#     309 """Forward pass through C2f layer."""
#     310 y = list(self.cv1(x).chunk(2, 1))
# --> 311 y.extend(m(y[-1]) for m in self.m)
#     312 return self.cv2(torch.cat(y, 1))
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:311, in <genexpr>(.0)
#     309 """Forward pass through C2f layer."""
#     310 y = list(self.cv1(x).chunk(2, 1))
# --> 311 y.extend(m(y[-1]) for m in self.m)
#     312 return self.cv2(torch.cat(y, 1))
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:1377, in PSABlock.forward(self, x)
#    1368 """Execute a forward pass through PSABlock.
#    1369
#    1370 Args:
#    (...)
#    1374     (torch.Tensor): Output tensor after attention and feed-forward processing.
#    1375 """
#    1376 x = x + self.attn(x) if self.add else self.attn(x)
# -> 1377 x = x + self.ffn(x) if self.add else self.ffn(x)
#    1378 return x
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 7.65 GiB of which 543.19 MiB is free. Process 544839 has 2.79 GiB memory in use. Process 545619 has 1.36 GiB memory in use. Process 546227 has 762.00 MiB memory in use. Including non-PyTorch memory, this process has 1.13 GiB memory in use. Of the allocated memory 876.50 MiB is allocated by PyTorch, and 51.50 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
